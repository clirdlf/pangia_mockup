# %%
# !pip install pysolr pyeuropeana python-dotenv
# Out:
# Requirement already satisfied: pysolr in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (3.9.0)
# Requirement already satisfied: pyeuropeana in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (0.1.7)
# Requirement already satisfied: python-dotenv in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (0.21.0)
# Requirement already satisfied: requests>=2.9.1 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from pysolr) (2.27.1)
# Requirement already satisfied: fire<0.5,>=0.4 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from pyeuropeana) (0.4.0)
# Requirement already satisfied: pandas<2.0,>=1.3 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from pyeuropeana) (1.5.3)
# Requirement already satisfied: six in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from fire<0.5,>=0.4->pyeuropeana) (1.16.0)
# Requirement already satisfied: termcolor in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from fire<0.5,>=0.4->pyeuropeana) (2.1.1)
# Requirement already satisfied: numpy>=1.20.3 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from pandas<2.0,>=1.3->pyeuropeana) (1.23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from pandas<2.0,>=1.3->pyeuropeana) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from pandas<2.0,>=1.3->pyeuropeana) (2022.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from requests>=2.9.1->pysolr) (2022.9.24)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from requests>=2.9.1->pysolr) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from requests>=2.9.1->pysolr) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from requests>=2.9.1->pysolr) (3.4)

# %%
import requests
import json
import os

from pysolr import Solr

# %%
# %load_ext dotenv
# %dotenv

# %%
SOLR_ENDPOINT = 'http://localhost:8984/solr/pangia'
EUROPEANA_ENDPOINT = 'https://www.europeana.eu/api/v2/search.json'

params = {
    'query': 'climate',
    'rows': 100,
    'wskey': os.getenv("EUROPEANA_API_KEY")
}

solr = Solr(SOLR_ENDPOINT)

# %%
# https://github.com/europeana/rd-europeana-python-api#usage
import pyeuropeana.apis as apis
import pyeuropeana.utils as utils

results = apis.search(
    query = '*',
    # qf = '(skos_concept:"http://data.europeana.eu/concept/base/48" AND TYPE:IMAGE)',
    reusability = 'open AND permission',
    media = True,
    thumbnail = True,
    landingpage = True,
    colourpalette = '#0000FF',
    theme = 'photography',
    sort = 'europeana_id',
    profile = 'rich',
    rows = 10,
) # this gives you full response metadata along with cultural heritage object metadata

# print(results)

# use this utility function to transform a subset of the cultural heritage object metadata
# into a readable Pandas DataFrame
# dataframe = utils.search2df(results)
# dataframe
# Out:
# {'apikey': 'rvKVUnBrg', 'success': True, 'requestNumber': 999, 'itemsCount': 10, 'totalResults': 218, 'nextCursor': 'AoE3LzkxNjEyMy9TTE1faXRlbV80MTEyNTk=', 'items': [{'completeness': 7, 'country': ['France'], 'dataProvider': ['National Library of France'], 'dcCreator': ['Cande, Daniel (1938-....). Photographe'], 'dcCreatorLangAware': {'def': ['Cande, Daniel (1938-....). Photographe']}, 'dcDescription': ['Appartient à l’ensemble documentaire : PhoSpec1'], 'dcDescriptionLangAware': {'def': ['Appartient à l’ensemble documentaire : PhoSpec1']}, 'dcLanguage': ['fra', 'fra'], 'dcLanguageLangAware': {'def': ['fra', 'fra']}, 'dcSubjectLangAware': {'fre': ['Opéra national de Paris. Ballet -- Photographies']}, 'dcTitleLangAware': {'def': ['[Recueil. Photographies. Hommage à Alwin Nikolaïs. Paris. Opéra Garnier. 1994 / Daniel Cande]']}, 'dcTypeLangAware': {'def': ['http://data.europeana.eu/concept/48'], 'fre': ['image fixe', 'photographie'], 'eng': ['image', 'still image', 'photograph']}, 'edmConcept': ['http://data.europeana.eu/concept/48'], 'edmConceptLabel': [{'def': 'Fotografie'}, {'def': 'Фотография'}, {'def': 'Valokuva'}, {'def': 'Fotografia'}, {'def': 'Снимка'}, {'def': 'Fotografija'}, {'def': 'Fotografija'}, {'def': 'Fotoattēls'}, {'def': 'Photographie'}, {'def': 'Fénykép'}, {'def': 'Fotograf'}, {'def': 'Fotografija'}, {'def': 'Grianghraf'}, {'def': 'Fotografia'}, {'def': 'Fotografi'}, {'def': 'Fotografija'}, {'def': 'Φωτογραφία'}, {'def': 'Photograph'}, {'def': 'Foto'}, {'def': 'Fotografía'}, {'def': 'Foto'}, {'def': 'Fotografie'}, {'def': 'Fotografia'}, {'def': 'Fotografi'}, {'def': 'Fotografie'}, {'def': 'Foto'}], 'edmConceptPrefLabelLangAware': {'de': ['Fotografie'], 'ru': ['Фотография'], 'fi': ['Valokuva'], 'pt': ['Fotografia'], 'bg': ['Снимка'], 'lt': ['Fotografija'], 'hr': ['Fotografija'], 'lv': ['Fotoattēls'], 'fr': ['Photographie'], 'hu': ['Fénykép'], 'sk': ['Fotograf'], 'sl': ['Fotografija'], 'ga': ['Grianghraf'], 'ca': ['Fotografia'], 'sv': ['Fotografi'], 'mt': ['Fotografija'], 'el': ['Φωτογραφία'], 'en': ['Photograph'], 'it': ['Foto'], 'es': ['Fotografía'], 'et': ['Foto'], 'cs': ['Fotografie'], 'pl': ['Fotografia'], 'da': ['Fotografi'], 'ro': ['Fotografie'], 'nl': ['Foto']}, 'edmDatasetName': ['9200518_Ag_BnF_Gallica_typedoc_images'], 'edmIsShownAt': ['http://gallica.bnf.fr/ark:/12148/btv1b9080431f'], 'edmIsShownBy': ['http://gallica.bnf.fr/iiif/ark:/12148/btv1b9080431f/f1/full/512,/0/native.jpg'], 'edmPreview': ['https://api.europeana.eu/thumbnail/v2/url.json?uri=https%3A%2F%2Fgallica.bnf.fr%2Fiiif%2Fark%3A%2F12148%2Fbtv1b9080431f%2Ff1%2Ffull%2F512%2C%2F0%2Fnative.jpg&type=IMAGE'], 'edmTimespan': ['http://semium.org/time/AD2xxx', 'http://semium.org/time/Time', 'http://semium.org/time/ChronologicalPeriod', 'http://semium.org/time/19xx'], 'edmTimespanLabel': [{'def': 'Second millenium AD'}, {'def': 'Second millenium AD, years 1001-2000'}, {'def': 'Time'}, {'def': 'Chronological period'}, {'def': '20-th'}, {'def': '20th'}, {'def': '20th century'}, {'def': '2e millénaire après J.-C.'}, {'def': '20e siècle'}, {'def': '20й век'}, {'def': '20..'}, {'def': '20??'}, {'def': '20e'}, {'def': '20de eeuw'}], 'edmTimespanLabelLangAware': {'ru': ['20й век'], 'def': ['20..', '20??', '20e'], 'en': ['Second millenium AD', 'Second millenium AD, years 1001-2000', 'Time', 'Chronological period', '20-th', '20th', '20th century'], 'fr': ['2e millénaire après J.-C.', '20e siècle'], 'nl': ['20de eeuw']}, 'europeanaCollectionName': ['9200518_Ag_BnF_Gallica_typedoc_images'], 'europeanaCompleteness': 7, 'guid': 'https://www.europeana.eu/item/9200518/ark__12148_btv1b9080431f?utm_source=api&utm_medium=api&utm_campaign=rvKVUnBrg', 'id': '/9200518/ark__12148_btv1b9080431f', 'index': 0, 'language': ['fr'], 'link': 'https://api.europeana.eu/record/9200518/ark__12148_btv1b9080431f.json?wskey=rvKVUnBrg', 'organizations': ['http://data.europeana.eu/organization/1482250000002112001', 'http://data.europeana.eu/organization/1482250000002112001'], 'previewN ...

# %%
for item in results['items']:
    doc = {
            'id': item['id'],
            'title': item['title'],
            'description': item.get('description'),
            'thumbnail': item['edmPreview'],
            'record_url': item['link'],
            'licence': item['rights'],
            'provider': item['dataProvider']
        }
    
    solr.add(doc)
    
solr.commit()

solr.optimize()
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<response>\n\n<lst name="responseHeader">\n  <int name="status">0</int>\n  <int name="QTime">0</int>\n</lst>\n</response>\n'

# %%
results = solr.search("provider:*")
print("\nSaw {0} result(s).".format(len(results)))

for result in results:
    print("The title is '{0}'.".format(result['title']))
    print(result)
# Out:
# Saw 10 result(s).
# The title is '['CLIMATE ACTION - Preparation underway ahead of UN Climate Conference (COP 21) in Paris:- Opening remarks by Miguel ARIAS CAÑETE, Member of the EC in charge of Climate Action and Energy', 'CLIMATE ACTION - Preparation underway ahead of UN Climate Conference (COP 21) in Paris:- Opening remarks by Miguel ARIAS CAÑETE, Member of the EC in charge of Climate Action and Energy']'.
# {'id': '/2031901/I_107857_INT_1', 'title': ['CLIMATE ACTION - Preparation underway ahead of UN Climate Conference (COP 21) in Paris:- Opening remarks by Miguel ARIAS CAÑETE, Member of the EC in charge of Climate Action and Energy', 'CLIMATE ACTION - Preparation underway ahead of UN Climate Conference (COP 21) in Paris:- Opening remarks by Miguel ARIAS CAÑETE, Member of the EC in charge of Climate Action and Energy'], 'thumbnail': ['https://api.europeana.eu/thumbnail/v2/url.json?uri=http%3A%2F%2Fdefiris.ec.streamcloud.be%2Ffindmedia%2F17%2F107857%2FTHUMB_M_I107857INT1W.jpg&type=VIDEO'], 'record_url': ['https://api.europeana.eu/record/2031901/I_107857_INT_1.json?wskey=rvKVUnBrg'], 'licence': ['http://rightsstatements.org/vocab/InC/1.0/'], 'provider': ['Audiovisual Library of the European Commission'], '_version_': 1762158921653420032}
# The title is '['Climate regionalization of Serbia according to K&#246;ppen climate classification']'.
# {'id': '/92040/URN_RS_NAE_bad5797a_d26f_4368_a065_d535c0201468cho', 'title': ['Climate regionalization of Serbia according to K&#246;ppen climate classification'], 'thumbnail': ['https://api.europeana.eu/thumbnail/v2/url.json?uri=http%3A%2F%2Fdoiserbia.nb.rs%2Fimages%2Fdoi%2F03507599_0.jpg&type=TEXT'], 'record_url': ['https://api.europeana.eu/record/92040/URN_RS_NAE_bad5797a_d26f_4368_a065_d535c0201468cho.json?wskey=rvKVUnBrg'], 'licence': ['http://creativecommons.org/licenses/by-nc-nd/4.0/'], 'provider': ['National Library of Serbia'], '_version_': 1762158921661808640}
# The title is '['Terrestrial climate globe', 'Terrestrial climate globe', 'Terrestrial climate globe']'.
# {'id': '/2022362/_Royal_Museums_Greenwich__http___collections_rmg_co_uk_collections_objects_19891', 'title': ['Terrestrial climate globe', 'Terrestrial climate globe', 'Terrestrial climate globe'], 'thumbnail': ['https://api.europeana.eu/thumbnail/v2/url.json?uri=http%3A%2F%2Fcollections.rmg.co.uk%2FmediaLib%2F398%2Fmedia-398631%2Flarge.jpg&type=IMAGE'], 'record_url': ['https://api.europeana.eu/record/2022362/_Royal_Museums_Greenwich__http___collections_rmg_co_uk_collections_objects_19891.json?wskey=rvKVUnBrg'], 'licence': ['http://creativecommons.org/licenses/by-nc-sa/4.0/'], 'provider': ['Royal Museums Greenwich'], '_version_': 1762158921668100096}
# The title is '['Climate adapted houses in Iran: Hot, cold and humid climate']'.
# {'id': '/92040/URN_RS_NAE_7e8d43a1_637c_4d06_a791_6877d5964e61cho', 'title': ['Climate adapted houses in Iran: Hot, cold and humid climate'], 'thumbnail': ['https://api.europeana.eu/thumbnail/v2/url.json?uri=http%3A%2F%2Fdoiserbia.nb.rs%2Fimages%2Fdoi%2F03544605_0.jpg&type=TEXT'], 'record_url': ['https://api.europeana.eu/record/92040/URN_RS_NAE_7e8d43a1_637c_4d06_a791_6877d5964e61cho.json?wskey=rvKVUnBrg'], 'licence': ['http://creativecommons.org/licenses/by-nc-nd/4.0/'], 'provider': ['National Library of Serbia'], '_version_': 1762158921672294400}
# The title is '['CLIMATE ACTION - G7 sends powerful message on climate change:- announcement', 'CLIMATE ACTION - G7 sends powerful message on climate change:- announcement']'.
# {'id': '/2031901/I_104351_INT_1', 'title': ['CLIMATE ACTION - G7 sends powerful message on climate change:- announcement', 'CLIMATE ACTION - G7 sends powerful message on climate change:- announcement'], 'thumbnail': ['https://api.europeana.eu/thumbnail/v2/url.json?uri=http%3A%2F%2Fdefiris.ec.streamcloud.be%2Ffindmedia%2F11%2F104351%2FTHUMB_M_I104351INT1W_07.jpg&type=VIDEO'], 'record_url': ['https://api.europeana.eu/record/2031901/I_104351_INT_1.json?wskey=rvKVUnBrg'], 'licence': ['http://rightsstatements.org/vocab/InC/1.0/'], 'provider': ['Audiovisual Library of the European Commission'], '_version_': 1762158921679634432}
# The title is '['Opening remarks Miguel ARIAS CAÑETE, Member of the EC in charge of Climate Action and Energy on the Energy and Climate Summer Package', 'Opening remarks Miguel ARIAS CAÑETE, Member of the EC in charge of Climate Action and Energy on the Energy and Climate Summer Package']'.
# {'id': '/2031901/I_107227_INT_1', 'title': ['Opening remarks Miguel ARIAS CAÑETE, Member of the EC in charge of Climate Action and Energy on the Energy and Climate Summer Package', 'Opening remarks Miguel ARIAS CAÑETE, Member of the EC in charge of Climate Action and Energy on the Energy and Climate Summer Package'], 'thumbnail': ['https://api.europeana.eu/thumbnail/v2/url.json?uri=http%3A%2F%2Fdefiris.ec.streamcloud.be%2Ffindmedia%2F07%2F107227%2FTHUMB_M_I107227INT1W.jpg&type=VIDEO'], 'record_url': ['https://api.europeana.eu/record/2031901/I_107227_INT_1.json?wskey=rvKVUnBrg'], 'licence': ['http://rightsstatements.org/vocab/InC/1.0/'], 'provider': ['Audiovisual Library of the European Commission'], '_version_': 1762158921683828736}
# The title is '['Seeking Climate Justice A Critical Response to Singer']'.
# {'id': '/9200111/BibliographicResource_1000085996036', 'title': ['Seeking Climate Justice A Critical Response to Singer'], 'thumbnail': ['https://api.europeana.eu/thumbnail/v2/url.json?uri=http%3A%2F%2Fliu.diva-portal.org%2Fsmash%2Fget%2Fdiva2%3A398949%2FFULLTEXT01&type=TEXT'], 'record_url': ['https://api.europeana.eu/record/9200111/BibliographicResource_1000085996036.json?wskey=rvKVUnBrg'], 'licence': ['http://rightsstatements.org/vocab/InC/1.0/'], 'provider': ['Uppsala University'], '_version_': 1762158921686974464}
# The title is '["CLIMATE ACTION - US President Obama's Plan to Fight Climate Change:- Q&A by Cecilia MALMSTRÖM, Member of the EC in\ncharge of Trade", "CLIMATE ACTION - US President Obama's Plan to Fight Climate Change:- Q&A by Cecilia MALMSTRÖM, Member of the EC in\ncharge of Trade"]'.
# {'id': '/2031901/I_107723_INT_1', 'title': ["CLIMATE ACTION - US President Obama's Plan to Fight Climate Change:- Q&A by Cecilia MALMSTRÖM, Member of the EC in\ncharge of Trade", "CLIMATE ACTION - US President Obama's Plan to Fight Climate Change:- Q&A by Cecilia MALMSTRÖM, Member of the EC in\ncharge of Trade"], 'thumbnail': ['https://api.europeana.eu/thumbnail/v2/url.json?uri=http%3A%2F%2Fdefiris.ec.streamcloud.be%2Ffindmedia%2F03%2F107723%2FTHUMB_M_I107723INT1W.jpg&type=VIDEO'], 'record_url': ['https://api.europeana.eu/record/2031901/I_107723_INT_1.json?wskey=rvKVUnBrg'], 'licence': ['http://rightsstatements.org/vocab/InC/1.0/'], 'provider': ['Audiovisual Library of the European Commission'], '_version_': 1762158921690120192}
# The title is '['CLIMATE ACTION - 2030 framework for climate and energy:- Q&A', 'CLIMATE ACTION - 2030 framework for climate and energy:- Q&A']'.
# {'id': '/2031901/I_085551_INT_1', 'title': ['CLIMATE ACTION - 2030 framework for climate and energy:- Q&A', 'CLIMATE ACTION - 2030 framework for climate and energy:- Q&A'], 'thumbnail': ['https://api.europeana.eu/thumbnail/v2/url.json?uri=http%3A%2F%2Fdefiris.ec.streamcloud.be%2Ffindmedia%2F11%2F085551%2FTHUMB_M_I085551INT1H.jpg&type=VIDEO'], 'record_url': ['https://api.europeana.eu/record/2031901/I_085551_INT_1.json?wskey=rvKVUnBrg'], 'licence': ['http://rightsstatements.org/vocab/InC/1.0/'], 'provider': ['Audiovisual Library of the European Commission'], '_version_': 1762158921692217344}
# The title is '['Second Assessment of Climate Change for the Baltic Sea Basin']'.
# {'id': '/9200235/book_10_1007_978_3_319_16006_1', 'title': ['Second Assessment of Climate Change for the Baltic Sea Basin'], 'thumbnail': ['https://api.europeana.eu/thumbnail/v2/url.json?uri=http%3A%2F%2Fwww.doabooks.org%2Fdoab%2F%3Ffunc%3Dcover%26rid%3D17437&type=TEXT'], 'record_url': ['https://api.europeana.eu/record/9200235/book_10_1007_978_3_319_16006_1.json?wskey=rvKVUnBrg'], 'licence': ['http://creativecommons.org/licenses/by-nc/4.0/'], 'provider': ['Open Access Publishing in European Networks Foundation'], '_version_': 1762158921699557376}
