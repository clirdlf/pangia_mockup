# %%
# !pip install pysolr pyeuropeana python-dotenv pyyaml
# Out:
# Requirement already satisfied: pysolr in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (3.9.0)
# Requirement already satisfied: pyeuropeana in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (0.1.7)
# Requirement already satisfied: python-dotenv in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (0.21.0)
# Requirement already satisfied: pyyaml in /Users/wgraham/.local/lib/python3.9/site-packages (6.0)
# Collecting python-frontmatter
#   Downloading python_frontmatter-1.0.0-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: requests>=2.9.1 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from pysolr) (2.27.1)
# Requirement already satisfied: fire<0.5,>=0.4 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from pyeuropeana) (0.4.0)
# Requirement already satisfied: pandas<2.0,>=1.3 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from pyeuropeana) (1.5.3)
# Requirement already satisfied: six in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from fire<0.5,>=0.4->pyeuropeana) (1.16.0)
# Requirement already satisfied: termcolor in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from fire<0.5,>=0.4->pyeuropeana) (2.1.1)
# Requirement already satisfied: numpy>=1.20.3 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from pandas<2.0,>=1.3->pyeuropeana) (1.23.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from pandas<2.0,>=1.3->pyeuropeana) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from pandas<2.0,>=1.3->pyeuropeana) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from requests>=2.9.1->pysolr) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from requests>=2.9.1->pysolr) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from requests>=2.9.1->pysolr) (1.26.12)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/wgraham/.pyenv/versions/3.9.13/lib/python3.9/site-packages (from requests>=2.9.1->pysolr) (2.0.12)
# Installing collected packages: python-frontmatter
# Successfully installed python-frontmatter-1.0.0

# %%
import requests
import json
import os
import yaml
import re

# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
# get 10 records from data.gov
CKAN_ENDPOINT = 'https://catalog.data.gov/api/3/action/package_search'
params = {
    'q': '*:*',
    'rows': 10,
    'start': 0,
    'sort': 'metadata_modified desc'
}

# Get the data
response = requests.get(CKAN_ENDPOINT, params=params)
data = json.loads(response.text)
# Out:
# {'help': 'https://catalog.data.gov/api/3/action/help_show?name=package_search',
#  'success': True,
#  'result': {'count': 250686,
#   'facets': {},
#   'results': [{'author': None,
#     'author_email': None,
#     'creator_user_id': '2b785922-9f13-491b-a3c2-2a40acbd80c2',
#     'id': '31354610-c274-400b-bb64-31aaf8086b17',
#     'isopen': False,
#     'license_id': 'other-license-specified',
#     'license_title': 'other-license-specified',
#     'maintainer': 'HealthData.gov Team',
#     'maintainer_email': 'HealthData@hhs.gov',
#     'metadata_created': '2022-01-25T02:04:26.214564',
#     'metadata_modified': '2023-04-02T18:35:42.496083',
#     'name': 'covid-19-public-therapeutic-locator',
#     'notes': "Locations of publicly available COVID-19 Therapeutics. Dataset only includes locations for Evusheld (monoclonal antibody), Molnupiravir (antiviral), and Paxlovid (Antiviral). COVID-19 therapeutics require a prescription to obtain. Limitations: public contact information.\n\n<b> To filter, click 'View Data' below, then 'Filter.' To save your view, click 'Save as,' and this configuration will be saved in your profile under 'My Assets.' <u>Please try not to publish dataset publicly, unless necessary.</b></u>\n\nOn 1/3/2022 - The following changes were made to this dataset.\n- Dropped the Expected Deliver Date column - This was a derived field set to 3 days after the Last Order Date field.\n- Added the following fields\n   Last Date Delivered\n   Total Courses\n   Courses Available\n   Courses Available Date\n\nOn 1/4/2022 - Added Geocoded Address\n\nOn 1/11/2022 - Added NPI - National Provider Identifier\n\nOn 2/18/2022 - Added new therapeutics, Bebtelovimab & Sotrovimab.\n\nOn 3/16/2022 - Dropped the following columns\n      - last_order_date\n      - last_date_delivered\n      - total_courses\n      - courses_available_date\n   Added the following columns\n      - facility_id\n      - last_report_date\n      - grantee_code\n      - provider_pin\n      - state_provider_pin\n\nOn 3/31/2022 - Dropped the following columns\n      - facility_id\n      - grantee_code\n      - provider_pin\n      - state_provider_pin\n   Added the following columns\n      - provider_status\n      - provider_note",
#     'num_resources': 4,
#     'num_tags': 3,
#     'organization': {'id': '2c2fc21f-21d0-4450-af01-cf8c69b44156',
#      'name': 'hhs-gov',
#      'title': 'U.S. Department of Health & Human Services',
#      'type': 'organization',
#      'description': '',
#      'image_url': 'https://www.hhs.gov/sites/default/files/web/images/seal_blue_gold_hi_res.jpg',
#      'created': '2020-11-10T14:14:03.176362',
#      'is_organization': True,
#      'approval_status': 'approved',
#      'state': 'active'},
#     'owner_org': '2c2fc21f-21d0-4450-af01-cf8c69b44156',
#     'private': False,
#     'state': 'active',
#     'title': 'COVID-19 Public Therapeutic Locator',
#     'type': 'dataset',
#     'url': None,
#     'version': None,
#     'extras': [{'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'source_hash',
#       'value': 'efcbdd473305f86f4fc67b097f551f13083452cb'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'bureauCode', 'value': ['009:00']},
#      {'key': 'dataQuality', 'value': True},
#      {'key': 'identifier',
#       'value': 'https://healthdata.gov/api/views/rxn6-qnx8'},
#      {'key': 'issued', 'value': '2022-03-31'},
#      {'key': 'landingPage', 'value': 'https://healthdata.gov/d/rxn6-qnx8'},
#      {'key': 'language', 'value': ['English']},
#      {'key': 'license', 'value': 'https://www.usa.gov/government-works'},
#      {'key': 'modified', 'value': '2023-04-02'},
#      {'key': 'programCode', 'value': ['009:028']},
#      {'key': 'publisher',
#       'value': 'U.S. Department of Health & Human Services'},
#      {'key': 'theme', 'value': ['Health']},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'catalog_@id', 'value': 'https://healthdata.gov/data.json'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_object_id',
#       'value': '526c906c-50da-4824-bbb5-a03b555c3c8e'},
#      {'key': 'harvest_source_id',
#       'value': '651e43b2-321c-4e4c-b86a-835cfc342cb0'},
#      {'key': 'harvest_source_title', 'value': 'Healthdata.gov'}],
#     'resources': [{'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2022-01-25T02:04:26.263565',
#       'description': '',
#       'format': 'CSV',
#       'hash': '',
#       'id': '170281f0-a4f5-40a9-86aa-3c87923a3bb2',
#       'last_modified': None,
#       'metadata_modified': '2022-01-25T02:04:26.263565',
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Comma Separated Values File',
#       'no_real_name': True,
#       'package_id': '31354610-c274-400b-bb64-31aaf8086b17',
#       'position': 0,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/rxn6-qnx8/rows.csv?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2022-01-25T02:04:26.263589',
#       'describedBy': 'https://healthdata.gov/api/views/rxn6-qnx8/columns.rdf',
#       'describedByType': 'application/rdf+xml',
#       'description': '',
#       'format': 'RDF',
#       'hash': '',
#       'id': 'f701b0ec-1900-4821-9dbb-4ed7dad9743b',
#       'last_modified': None,
#       'metadata_modified': '2022-01-25T02:04:26.263589',
#       'mimetype': 'application/rdf+xml',
#       'mimetype_inner': None,
#       'name': 'RDF File',
#       'no_real_name': True,
#       'package_id': '31354610-c274-400b-bb64-31aaf8086b17',
#       'position': 1,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/rxn6-qnx8/rows.rdf?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2022-01-25T02:04:26.263599',
#       'describedBy': 'https://healthdata.gov/api/views/rxn6-qnx8/columns.json',
#       'describedByType': 'application/json',
#       'description': '',
#       'format': 'JSON',
#       'hash': '',
#       'id': 'd1c7af57-c793-49e7-8725-679198f7b007',
#       'last_modified': None,
#       'metadata_modified': '2022-01-25T02:04:26.263599',
#       'mimetype': 'application/json',
#       'mimetype_inner': None,
#       'name': 'JSON File',
#       'no_real_name': True,
#       'package_id': '31354610-c274-400b-bb64-31aaf8086b17',
#       'position': 2,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/rxn6-qnx8/rows.json?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2022-01-25T02:04:26.263604',
#       'describedBy': 'https://healthdata.gov/api/views/rxn6-qnx8/columns.xml',
#       'describedByType': 'application/xml',
#       'description': '',
#       'format': 'XML',
#       'hash': '',
#       'id': 'd4feda34-f08a-45be-b06c-2f865587d761',
#       'last_modified': None,
#       'metadata_modified': '2022-01-25T02:04:26.263604',
#       'mimetype': 'application/xml',
#       'mimetype_inner': None,
#       'name': 'XML File',
#       'no_real_name': True,
#       'package_id': '31354610-c274-400b-bb64-31aaf8086b17',
#       'position': 3,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/rxn6-qnx8/rows.xml?accessType=DOWNLOAD',
#       'url_type': None}],
#     'tags': [{'display_name': 'covid-19',
#       'id': 'af0c031e-ec6e-482c-b12e-90c7c320c38d',
#       'name': 'covid-19',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'hhs-covid-19',
#       'id': '2e6f5255-415b-47af-ab10-42b3b38e6919',
#       'name': 'hhs-covid-19',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'theraputic-care',
#       'id': '69fda905-542d-4df5-b323-62e2843d8c8d',
#       'name': 'theraputic-care',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'groups': [],
#     'relationships_as_subject': [],
#     'relationships_as_object': []},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '2b785922-9f13-491b-a3c2-2a40acbd80c2',
#     'id': 'd59c49ba-4160-4324-9bb3-b6ccfa7d83ff',
#     'isopen': False,
#     'license_id': 'other-license-specified',
#     'license_title': 'other-license-specified',
#     'maintainer': 'National Library of Medicine',
#     'maintainer_email': 'custserv@nlm.nih.gov',
#     'metadata_created': '2022-02-17T08:09:48.256937',
#     'metadata_modified': '2023-04-02T18:30:32.071836',
#     'name': 'learning-resources-database-f3a5b',
#     'notes': 'The Learning Resources Database is a catalog of interactive tutorials, videos, online classes, finding aids, and other instructional resources on National Library of Medicine (NLM) products and services. Resources may be available for immediate use via a browser or downloadable for use in course management systems.',
#     'num_resources': 4,
#     'num_tags': 3,
#     'organization': {'id': '2c2fc21f-21d0-4450-af01-cf8c69b44156',
#      'name': 'hhs-gov',
#      'title': 'U.S. Department of Health & Human Services',
#      'type': 'organization',
#      'description': '',
#      'image_url': 'https://www.hhs.gov/sites/default/files/web/images/seal_blue_gold_hi_res.jpg',
#      'created': '2020-11-10T14:14:03.176362',
#      'is_organization': True,
#      'approval_status': 'approved',
#      'state': 'active'},
#     'owner_org': '2c2fc21f-21d0-4450-af01-cf8c69b44156',
#     'private': False,
#     'state': 'active',
#     'title': 'Learning Resources Database',
#     'type': 'dataset',
#     'url': None,
#     'version': None,
#     'extras': [{'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'source_hash',
#       'value': '7336bff6d89405376a4fdf1211a96ee4f9d04e89'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'bureauCode', 'value': ['009:25']},
#      {'key': 'identifier',
#       'value': 'https://datadiscovery.nlm.nih.gov/api/views/khy6-95gu'},
#      {'key': 'issued', 'value': '2022-06-29'},
#      {'key': 'landingPage', 'value': 'https://learn.nlm.nih.gov/'},
#      {'key': 'license',
#       'value': 'http://opendefinition.org/licenses/odc-odbl/'},
#      {'key': 'modified', 'value': '2023-04-01'},
#      {'key': 'programCode', 'value': ['009:041']},
#      {'key': 'publisher', 'value': 'National Library of Medicine'},
#      {'key': 'theme', 'value': ['Other']},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'catalog_@id', 'value': 'https://healthdata.gov/data.json'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_object_id',
#       'value': '431c509c-995c-4305-b654-bf642e3d2654'},
#      {'key': 'harvest_source_id',
#       'value': '651e43b2-321c-4e4c-b86a-835cfc342cb0'},
#      {'key': 'harvest_source_title', 'value': 'Healthdata.gov'}],
#     'resources': [{'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2022-02-17T08:09:48.284259',
#       'description': '',
#       'format': 'CSV',
#       'hash': '',
#       'id': '15f4bb76-bd7a-4dd2-a6e0-32e634da614e',
#       'last_modified': None,
#       'metadata_modified': '2022-02-17T08:09:48.284259',
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Comma Separated Values File',
#       'no_real_name': True,
#       'package_id': 'd59c49ba-4160-4324-9bb3-b6ccfa7d83ff',
#       'position': 0,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://datadiscovery.nlm.nih.gov/api/views/khy6-95gu/rows.csv?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2022-02-17T08:09:48.284266',
#       'description': '',
#       'format': 'RDF',
#       'hash': '',
#       'id': 'dde5db44-faf1-4992-ab79-6b22d3ec41c5',
#       'last_modified': None,
#       'metadata_modified': '2022-02-17T08:09:48.284266',
#       'mimetype': 'application/rdf+xml',
#       'mimetype_inner': None,
#       'name': 'RDF File',
#       'no_real_name': True,
#       'package_id': 'd59c49ba-4160-4324-9bb3-b6ccfa7d83ff',
#       'position': 1,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://datadiscovery.nlm.nih.gov/api/views/khy6-95gu/rows.rdf?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2022-02-17T08:09:48.284269',
#       'description': '',
#       'format': 'JSON',
#       'hash': '',
#       'id': '71a167ba-7cb0-4c7a-8c28-f3a468b085a9',
#       'last_modified': None,
#       'metadata_modified': '2022-02-17T08:09:48.284269',
#       'mimetype': 'application/json',
#       'mimetype_inner': None,
#       'name': 'JSON File',
#       'no_real_name': True,
#       'package_id': 'd59c49ba-4160-4324-9bb3-b6ccfa7d83ff',
#       'position': 2,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://datadiscovery.nlm.nih.gov/api/views/khy6-95gu/rows.json?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2022-02-17T08:09:48.284272',
#       'description': '',
#       'format': 'XML',
#       'hash': '',
#       'id': '67fd56dc-4030-4951-8f76-81f05523311e',
#       'last_modified': None,
#       'metadata_modified': '2022-02-17T08:09:48.284272',
#       'mimetype': 'application/xml',
#       'mimetype_inner': None,
#       'name': 'XML File',
#       'no_real_name': True,
#       'package_id': 'd59c49ba-4160-4324-9bb3-b6ccfa7d83ff',
#       'position': 3,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://datadiscovery.nlm.nih.gov/api/views/khy6-95gu/rows.xml?accessType=DOWNLOAD',
#       'url_type': None}],
#     'tags': [{'display_name': 'education',
#       'id': '62c3cc27-f242-47b5-a9be-4e0c756e841f',
#       'name': 'education',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'training-and-instruction',
#       'id': '05315209-636a-4411-acfe-919a3f3e5789',
#       'name': 'training-and-instruction',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'videos',
#       'id': 'd2491527-4564-4c5c-a814-8f44d30bb823',
#       'name': 'videos',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'groups': [],
#     'relationships_as_subject': [],
#     'relationships_as_object': []},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '2b785922-9f13-491b-a3c2-2a40acbd80c2',
#     'id': '5bdd90ee-9299-485c-839f-838966392dc5',
#     'isopen': False,
#     'license_id': 'other-license-specified',
#     'license_title': 'other-license-specified',
#     'maintainer': 'HealthData.gov Team',
#     'maintainer_email': 'HealthData@hhs.gov',
#     'metadata_created': '2021-03-29T23:34:51.164618',
#     'metadata_modified': '2023-04-02T18:29:20.204889',
#     'name': 'covid-19-diagnostic-laboratory-testing-pcr-testing-time-series-80872',
#     'notes': '<br>This time series dataset includes viral COVID-19 laboratory test [Polymerase chain reaction (PCR)] results from over 1,000 U.S. laboratories and testing locations including commercial and reference laboratories, public health laboratories, hospital laboratories, and other testing locations. Data are reported to state and jurisdictional health departments in accordance with applicable state or local law and in accordance with the Coronavirus Aid, Relief, and Economic Security (CARES) Act (<a href="https://www.hhs.gov/sites/default/files/covid-19-laboratory-data-reporting-guidance.pdf">CARES Act Section 18115</a>).</br>\n<br>Data are <b>provisional and subject to change</b>.</br>\n<br>Data presented here is representative of diagnostic specimens being tested - not individual people - and excludes serology tests where possible. Data presented might not represent the most current counts for the most recent 3 days due to the time it takes to report testing information. The data may also not include results from all potential testing sites within the jurisdiction (e.g., non-laboratory or point of care test sites) and therefore reflect the majority, but not all, of COVID-19 testing being conducted in the United States.</br>\n<br><b>Sources:</b> CDC COVID-19 Electronic Laboratory Reporting (CELR), Commercial Laboratories, State Public Health Labs, In-House Hospital Labs</br>\n<br>Data for each state is sourced from either data submitted directly by the state health department via COVID-19 electronic laboratory reporting (CELR), or a combination of commercial labs, public health labs, and in-house hospital labs. Data is taken from CELR for states that either submit line level data or submit aggregate counts which do not include serology tests.</br>',
#     'num_resources': 4,
#     'num_tags': 4,
#     'organization': {'id': '2c2fc21f-21d0-4450-af01-cf8c69b44156',
#      'name': 'hhs-gov',
#      'title': 'U.S. Department of Health & Human Services',
#      'type': 'organization',
#      'description': '',
#      'image_url': 'https://www.hhs.gov/sites/default/files/web/images/seal_blue_gold_hi_res.jpg',
#      'created': '2020-11-10T14:14:03.176362',
#      'is_organization': True,
#      'approval_status': 'approved',
#      'state': 'active'},
#     'owner_org': '2c2fc21f-21d0-4450-af01-cf8c69b44156',
#     'private': False,
#     'state': 'active',
#     'title': 'COVID-19 Diagnostic Laboratory Testing (PCR Testing) Time Series',
#     'type': 'dataset',
#     'url': None,
#     'version': None,
#     'extras': [{'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'source_hash',
#       'value': '615734d2ce7194eb47391ef0403d0383cd8df6c6'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'accrualPeriodicity', 'value': 'R/P1D'},
#      {'key': 'bureauCode', 'value': ['009:00']},
#      {'key': 'dataQuality', 'value': True},
#      {'key': 'identifier',
#       'value': 'https://healthdata.gov/api/views/j8mb-icvb'},
#      {'key': 'issued', 'value': '2020-12-15'},
#      {'key': 'landingPage', 'value': 'https://healthdata.gov/d/j8mb-icvb'},
#      {'key': 'language', 'value': ['English']},
#      {'key': 'license',
#       'value': 'http://opendatacommons.org/licenses/by/1.0/'},
#      {'key': 'modified', 'value': '2023-04-02'},
#      {'key': 'programCode', 'value': ['009:028']},
#      {'key': 'publisher',
#       'value': 'U.S. Department of Health & Human Services'},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'catalog_@id', 'value': 'https://healthdata.gov/data.json'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_object_id',
#       'value': 'adfb7235-e4d2-4788-a027-d7d25ffd8392'},
#      {'key': 'harvest_source_id',
#       'value': '651e43b2-321c-4e4c-b86a-835cfc342cb0'},
#      {'key': 'harvest_source_title', 'value': 'Healthdata.gov'}],
#     'resources': [{'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-03-29T23:34:51.211241',
#       'description': '',
#       'format': 'CSV',
#       'hash': '',
#       'id': 'd5f28e0c-2d47-4a53-a906-d1fdc784eaeb',
#       'last_modified': None,
#       'metadata_modified': '2021-03-29T23:34:51.211241',
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Comma Separated Values File',
#       'no_real_name': True,
#       'package_id': '5bdd90ee-9299-485c-839f-838966392dc5',
#       'position': 0,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/j8mb-icvb/rows.csv?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-03-29T23:34:51.211248',
#       'describedBy': 'https://healthdata.gov/api/views/j8mb-icvb/columns.rdf',
#       'describedByType': 'application/rdf+xml',
#       'description': '',
#       'format': 'RDF',
#       'hash': '',
#       'id': 'ef9a8f5a-556d-4174-ba09-b59425cd6bc7',
#       'last_modified': None,
#       'metadata_modified': '2021-03-29T23:34:51.211248',
#       'mimetype': 'application/rdf+xml',
#       'mimetype_inner': None,
#       'name': 'RDF File',
#       'no_real_name': True,
#       'package_id': '5bdd90ee-9299-485c-839f-838966392dc5',
#       'position': 1,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/j8mb-icvb/rows.rdf?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-03-29T23:34:51.211251',
#       'describedBy': 'https://healthdata.gov/api/views/j8mb-icvb/columns.json',
#       'describedByType': 'application/json',
#       'description': '',
#       'format': 'JSON',
#       'hash': '',
#       'id': 'fa2a8739-4887-4280-8c19-3b2caeb75bec',
#       'last_modified': None,
#       'metadata_modified': '2021-03-29T23:34:51.211251',
#       'mimetype': 'application/json',
#       'mimetype_inner': None,
#       'name': 'JSON File',
#       'no_real_name': True,
#       'package_id': '5bdd90ee-9299-485c-839f-838966392dc5',
#       'position': 2,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/j8mb-icvb/rows.json?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-03-29T23:34:51.211254',
#       'describedBy': 'https://healthdata.gov/api/views/j8mb-icvb/columns.xml',
#       'describedByType': 'application/xml',
#       'description': '',
#       'format': 'XML',
#       'hash': '',
#       'id': 'c52e610e-f08b-40b8-b0cf-6a2174774186',
#       'last_modified': None,
#       'metadata_modified': '2021-03-29T23:34:51.211254',
#       'mimetype': 'application/xml',
#       'mimetype_inner': None,
#       'name': 'XML File',
#       'no_real_name': True,
#       'package_id': '5bdd90ee-9299-485c-839f-838966392dc5',
#       'position': 3,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/j8mb-icvb/rows.xml?accessType=DOWNLOAD',
#       'url_type': None}],
#     'tags': [{'display_name': 'covid',
#       'id': 'a49e3d9c-92fd-4c4f-a6eb-f49224a27e73',
#       'name': 'covid',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'covid-19',
#       'id': 'af0c031e-ec6e-482c-b12e-90c7c320c38d',
#       'name': 'covid-19',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'covid19',
#       'id': 'c8b31fac-14b9-49e5-9b90-82089f277410',
#       'name': 'covid19',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'hhs-covid-19',
#       'id': '2e6f5255-415b-47af-ab10-42b3b38e6919',
#       'name': 'hhs-covid-19',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'groups': [],
#     'relationships_as_subject': [],
#     'relationships_as_object': []},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '2b785922-9f13-491b-a3c2-2a40acbd80c2',
#     'id': '187ac6e5-efdc-465a-aaf7-9ffbc1f6ffeb',
#     'isopen': False,
#     'license_id': 'other-license-specified',
#     'license_title': 'other-license-specified',
#     'maintainer': 'HealthData.gov Team',
#     'maintainer_email': 'HealthData@hhs.gov',
#     'metadata_created': '2021-03-29T23:34:19.122388',
#     'metadata_modified': '2023-04-02T18:27:48.511456',
#     'name': 'covid-19-reported-patient-impact-and-hospital-capacity-by-state-timeseries-cf58c',
#     'notes': 'The following dataset provides state-aggregated data for hospital utilization <b>in a timeseries format</b> dating back to January 1, 2020. These are derived from reports with facility-level granularity across three main sources: (1) HHS TeleTracking, (2) reporting provided directly to HHS Protect by state/territorial health departments on behalf of their healthcare facilities and (3) National Healthcare Safety Network (before July 15).\n\nThe file will be updated regularly and provides the latest values reported by each facility within the last four days for all time. This allows for a more comprehensive picture of the hospital utilization within a state by ensuring a hospital is represented, even if they miss a single day of reporting.\n\nNo statistical analysis is applied to account for non-response and/or to account for missing data.\n\nThe below table displays one value for each field (i.e., column). Sometimes, reports for a given facility will be provided to more than one reporting source: HHS TeleTracking, NHSN, and HHS Protect. When this occurs, to ensure that there are not duplicate reports, prioritization is applied to the numbers for each facility.\n\nOn April 27, 2022  the following pediatric fields were added:\n<li>all_pediatric_inpatient_bed_occupied\n<li>all_pediatric_inpatient_bed_occupied_coverage\n<li>all_pediatric_inpatient_beds\n<li>all_pediatric_inpatient_beds_coverage\n<li>previous_day_admission_pediatric_covid_confirmed_0_4\n<li>previous_day_admission_pediatric_covid_confirmed_0_4_coverage\n<li>previous_day_admission_pediatric_covid_confirmed_12_17\n<li>previous_day_admission_pediatric_covid_confirmed_12_17_coverage\n<li> previous_day_admission_pediatric_covid_confirmed_5_11\n<li>previous_day_admission_pediatric_covid_confirmed_5_11_coverage\n<li>previous_day_admission_pediatric_covid_confirmed_unknown\n<li>previous_day_admission_pediatric_covid_confirmed_unknown_coverage\n<li>staffed_icu_pediatric_patients_confirmed_covid\n<li>staffed_icu_pediatric_patients_confirmed_covid_coverage\n<li>staffed_pediatric_icu_bed_occupancy\n<li>staffed_pediatric_icu_bed_occupancy_coverage\n<li>total_staffed_pediatric_icu_beds\n<li>total_staffed_pediatric_icu_beds_coverage\n\nOn January 19, 2022, the following fields have been added to this dataset:\n<li>inpatient_beds_used_covid\n<li>inpatient_beds_used_covid_coverage\n\nOn September 17, 2021, this data set has had the following fields added:\n<li>icu_patients_confirmed_influenza,\n<li>icu_patients_confirmed_influenza_coverage,\n<li>previous_day_admission_influenza_confirmed,\n<li>previous_day_admission_influenza_confirmed_coverage,\n<li>previous_day_deaths_covid_and_influenza,\n<li>previous_day_deaths_covid_and_influenza_coverage,\n<li>previous_day_deaths_influenza,\n<li>previous_day_deaths_influenza_coverage,\n<li>total_patients_hospitalized_confirmed_influenza,\n<li>total_patients_hospitalized_confirmed_influenza_and_covid,\n<li>total_patients_hospitalized_confirmed_influenza_and_covid_coverage,\n<li>total_patients_hospitalized_confirmed_influenza_coverage\n\nOn September 13, 2021, this data set has had the following fields added:\n<li>on_hand_supply_therapeutic_a_casirivimab_imdevimab_courses,\n<li>on_hand_supply_therapeutic_b_bamlanivimab_courses,\n<li>on_hand_supply_therapeutic_c_bamlanivimab_etesevimab_courses,\n<li>previous_week_therapeutic_a_casirivimab_imdevimab_courses_used,\n<li>previous_week_therapeutic_b_bamlanivimab_courses_used,\n<li>previous_week_therapeutic_c_bamlanivimab_etesevimab_courses_used\n\nOn June 30, 2021, this data set has had the following fields added:\n<li>deaths_covid\n<li>deaths_covid_coverage\n\nOn April 30, 2021, this data set has had the following fields added:\n<li>previous_day_admission_adult_covid_confirmed_18-19\n<li>previous_day_admission_adult_covid_confirmed_18-19_coverage\n<li>previous_day_admission_adult_covid_confirmed_20-29_coverage\n<li>previous_day_admission_adult_covid_confirmed_30-39\n<li>previous_day_admi ...
#     'num_resources': 4,
#     'num_tags': 2,
#     'organization': {'id': '2c2fc21f-21d0-4450-af01-cf8c69b44156',
#      'name': 'hhs-gov',
#      'title': 'U.S. Department of Health & Human Services',
#      'type': 'organization',
#      'description': '',
#      'image_url': 'https://www.hhs.gov/sites/default/files/web/images/seal_blue_gold_hi_res.jpg',
#      'created': '2020-11-10T14:14:03.176362',
#      'is_organization': True,
#      'approval_status': 'approved',
#      'state': 'active'},
#     'owner_org': '2c2fc21f-21d0-4450-af01-cf8c69b44156',
#     'private': False,
#     'state': 'active',
#     'title': 'COVID-19 Reported Patient Impact and Hospital Capacity by State Timeseries',
#     'type': 'dataset',
#     'url': None,
#     'version': None,
#     'extras': [{'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'source_hash',
#       'value': '47e480afa8f2b5daa8fac18857e13108be4d2d93'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'accrualPeriodicity', 'value': 'R/P1D'},
#      {'key': 'bureauCode', 'value': ['009:00']},
#      {'key': 'dataQuality', 'value': True},
#      {'key': 'identifier',
#       'value': 'https://healthdata.gov/api/views/g62h-syeh'},
#      {'key': 'issued', 'value': '2022-04-27'},
#      {'key': 'landingPage', 'value': 'https://healthdata.gov/d/g62h-syeh'},
#      {'key': 'language', 'value': ['English']},
#      {'key': 'license', 'value': 'https://www.usa.gov/government-works'},
#      {'key': 'modified', 'value': '2023-04-02'},
#      {'key': 'programCode', 'value': ['009:028']},
#      {'key': 'publisher',
#       'value': 'U.S. Department of Health & Human Services'},
#      {'key': 'theme', 'value': ['Hospital']},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'catalog_@id', 'value': 'https://healthdata.gov/data.json'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_object_id',
#       'value': '63ac99e2-eba8-4934-96b1-ec3ecf9e7ec5'},
#      {'key': 'harvest_source_id',
#       'value': '651e43b2-321c-4e4c-b86a-835cfc342cb0'},
#      {'key': 'harvest_source_title', 'value': 'Healthdata.gov'}],
#     'resources': [{'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-03-29T23:34:19.141242',
#       'description': '',
#       'format': 'CSV',
#       'hash': '',
#       'id': 'c9dbe388-10b5-4fa4-8a87-626eefc6e5c4',
#       'last_modified': None,
#       'metadata_modified': '2021-03-29T23:34:19.141242',
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Comma Separated Values File',
#       'no_real_name': True,
#       'package_id': '187ac6e5-efdc-465a-aaf7-9ffbc1f6ffeb',
#       'position': 0,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/g62h-syeh/rows.csv?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-03-29T23:34:19.141249',
#       'describedBy': 'https://healthdata.gov/api/views/g62h-syeh/columns.rdf',
#       'describedByType': 'application/rdf+xml',
#       'description': '',
#       'format': 'RDF',
#       'hash': '',
#       'id': '29b5403a-3893-415b-a735-af9ef57aa19b',
#       'last_modified': None,
#       'metadata_modified': '2021-03-29T23:34:19.141249',
#       'mimetype': 'application/rdf+xml',
#       'mimetype_inner': None,
#       'name': 'RDF File',
#       'no_real_name': True,
#       'package_id': '187ac6e5-efdc-465a-aaf7-9ffbc1f6ffeb',
#       'position': 1,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/g62h-syeh/rows.rdf?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-03-29T23:34:19.141252',
#       'describedBy': 'https://healthdata.gov/api/views/g62h-syeh/columns.json',
#       'describedByType': 'application/json',
#       'description': '',
#       'format': 'JSON',
#       'hash': '',
#       'id': '51c0a4a2-6c7e-4f2a-9914-8c3121c261a9',
#       'last_modified': None,
#       'metadata_modified': '2021-03-29T23:34:19.141252',
#       'mimetype': 'application/json',
#       'mimetype_inner': None,
#       'name': 'JSON File',
#       'no_real_name': True,
#       'package_id': '187ac6e5-efdc-465a-aaf7-9ffbc1f6ffeb',
#       'position': 2,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/g62h-syeh/rows.json?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-03-29T23:34:19.141255',
#       'describedBy': 'https://healthdata.gov/api/views/g62h-syeh/columns.xml',
#       'describedByType': 'application/xml',
#       'description': '',
#       'format': 'XML',
#       'hash': '',
#       'id': '3ef57361-bda1-4843-8aa4-ec9ccdafd034',
#       'last_modified': None,
#       'metadata_modified': '2021-03-29T23:34:19.141255',
#       'mimetype': 'application/xml',
#       'mimetype_inner': None,
#       'name': 'XML File',
#       'no_real_name': True,
#       'package_id': '187ac6e5-efdc-465a-aaf7-9ffbc1f6ffeb',
#       'position': 3,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/g62h-syeh/rows.xml?accessType=DOWNLOAD',
#       'url_type': None}],
#     'tags': [{'display_name': 'covid-19',
#       'id': 'af0c031e-ec6e-482c-b12e-90c7c320c38d',
#       'name': 'covid-19',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'hhs-covid-19',
#       'id': '2e6f5255-415b-47af-ab10-42b3b38e6919',
#       'name': 'hhs-covid-19',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'groups': [],
#     'relationships_as_subject': [],
#     'relationships_as_object': []},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '2b785922-9f13-491b-a3c2-2a40acbd80c2',
#     'id': '36d651a0-bcbc-44f4-99ed-476786042fa8',
#     'isopen': False,
#     'license_id': 'other-license-specified',
#     'license_title': 'other-license-specified',
#     'maintainer': 'CDC',
#     'maintainer_email': 'vaccinefinder@cdc.gov',
#     'metadata_created': '2021-11-10T07:44:08.780541',
#     'metadata_modified': '2023-04-02T18:25:22.620642',
#     'name': 'vaccines-gov-flu-vaccinating-provider-locations-7c548',
#     'notes': 'The Vaccines.gov dataset includes provider information for flu vaccine provider locations in the U.S. Vaccines.gov is powered by VaccineFinder.',
#     'num_resources': 4,
#     'num_tags': 8,
#     'organization': {'id': '2c2fc21f-21d0-4450-af01-cf8c69b44156',
#      'name': 'hhs-gov',
#      'title': 'U.S. Department of Health & Human Services',
#      'type': 'organization',
#      'description': '',
#      'image_url': 'https://www.hhs.gov/sites/default/files/web/images/seal_blue_gold_hi_res.jpg',
#      'created': '2020-11-10T14:14:03.176362',
#      'is_organization': True,
#      'approval_status': 'approved',
#      'state': 'active'},
#     'owner_org': '2c2fc21f-21d0-4450-af01-cf8c69b44156',
#     'private': False,
#     'state': 'active',
#     'title': 'Vaccines.gov: Flu vaccinating provider locations',
#     'type': 'dataset',
#     'url': None,
#     'version': None,
#     'extras': [{'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'source_hash',
#       'value': 'a12460e8036457a8f417264d496f29e818a22b02'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'bureauCode', 'value': ['009:20']},
#      {'key': 'identifier',
#       'value': 'https://data.cdc.gov/api/views/bugr-bbfr'},
#      {'key': 'issued', 'value': '2021-10-27'},
#      {'key': 'landingPage', 'value': 'https://data.cdc.gov/d/bugr-bbfr'},
#      {'key': 'license',
#       'value': 'http://opendefinition.org/licenses/odc-odbl/'},
#      {'key': 'modified', 'value': '2023-04-02'},
#      {'key': 'programCode', 'value': ['009:020']},
#      {'key': 'publisher',
#       'value': 'Centers for Disease Control and Prevention'},
#      {'key': 'theme', 'value': ['Flu Vaccinations']},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'catalog_@id', 'value': 'https://healthdata.gov/data.json'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_object_id',
#       'value': '6c5732ec-09df-4ecc-b0f0-a442e77ac6ca'},
#      {'key': 'harvest_source_id',
#       'value': '651e43b2-321c-4e4c-b86a-835cfc342cb0'},
#      {'key': 'harvest_source_title', 'value': 'Healthdata.gov'}],
#     'resources': [{'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-11-10T07:44:08.793400',
#       'description': '',
#       'format': 'CSV',
#       'hash': '',
#       'id': 'b6774b7f-864c-4597-acb7-5c13b0fa9cb0',
#       'last_modified': None,
#       'metadata_modified': '2021-11-10T07:44:08.793400',
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Comma Separated Values File',
#       'no_real_name': True,
#       'package_id': '36d651a0-bcbc-44f4-99ed-476786042fa8',
#       'position': 0,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://data.cdc.gov/api/views/bugr-bbfr/rows.csv?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-11-10T07:44:08.793406',
#       'description': '',
#       'format': 'RDF',
#       'hash': '',
#       'id': '86340990-f0c2-42c1-9ebc-5ad8eae5d22f',
#       'last_modified': None,
#       'metadata_modified': '2021-11-10T07:44:08.793406',
#       'mimetype': 'application/rdf+xml',
#       'mimetype_inner': None,
#       'name': 'RDF File',
#       'no_real_name': True,
#       'package_id': '36d651a0-bcbc-44f4-99ed-476786042fa8',
#       'position': 1,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://data.cdc.gov/api/views/bugr-bbfr/rows.rdf?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-11-10T07:44:08.793410',
#       'description': '',
#       'format': 'JSON',
#       'hash': '',
#       'id': '909eedb7-1f09-47f1-9056-10fd3718d57a',
#       'last_modified': None,
#       'metadata_modified': '2021-11-10T07:44:08.793410',
#       'mimetype': 'application/json',
#       'mimetype_inner': None,
#       'name': 'JSON File',
#       'no_real_name': True,
#       'package_id': '36d651a0-bcbc-44f4-99ed-476786042fa8',
#       'position': 2,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://data.cdc.gov/api/views/bugr-bbfr/rows.json?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-11-10T07:44:08.793412',
#       'description': '',
#       'format': 'XML',
#       'hash': '',
#       'id': '15d5a551-8bfc-4859-9b96-f3731a2c575f',
#       'last_modified': None,
#       'metadata_modified': '2021-11-10T07:44:08.793412',
#       'mimetype': 'application/xml',
#       'mimetype_inner': None,
#       'name': 'XML File',
#       'no_real_name': True,
#       'package_id': '36d651a0-bcbc-44f4-99ed-476786042fa8',
#       'position': 3,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://data.cdc.gov/api/views/bugr-bbfr/rows.xml?accessType=DOWNLOAD',
#       'url_type': None}],
#     'tags': [{'display_name': 'flu',
#       'id': 'a99230f1-ac4f-4866-ac27-4bec4dd3221d',
#       'name': 'flu',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'flu-shot',
#       'id': '51a1fa30-9190-49ae-b24d-c576dc498dff',
#       'name': 'flu-shot',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'flu-vaccination',
#       'id': 'e6c1e97b-c70a-4cb3-bd48-a50f7e80edbb',
#       'name': 'flu-vaccination',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'providers',
#       'id': 'b53afac9-e383-4006-8fe4-f85ad542b796',
#       'name': 'providers',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'vaccination-locations',
#       'id': '77e1c73d-9d08-4cb0-89ca-a46ddd7635d1',
#       'name': 'vaccination-locations',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'vaccination-sites',
#       'id': 'f860c105-454e-41f4-ac11-221285d34ed1',
#       'name': 'vaccination-sites',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'vaccinefinder',
#       'id': 'e04319d6-5cce-4a02-93d7-e95c16f1d96f',
#       'name': 'vaccinefinder',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'vaccines',
#       'id': '40551b83-4e94-457a-a083-5fc2065b8273',
#       'name': 'vaccines',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'groups': [],
#     'relationships_as_subject': [],
#     'relationships_as_object': []},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '2b785922-9f13-491b-a3c2-2a40acbd80c2',
#     'id': '93569e24-9a21-468d-b61f-00257c9a6b82',
#     'isopen': False,
#     'license_id': 'other-license-specified',
#     'license_title': 'other-license-specified',
#     'maintainer': 'CDC',
#     'maintainer_email': 'vaccinefinder@cdc.gov',
#     'metadata_created': '2021-07-09T13:31:43.221147',
#     'metadata_modified': '2023-04-02T18:25:16.938096',
#     'name': 'vaccines-gov-covid-19-vaccinating-provider-locations-181de',
#     'notes': 'The Vaccines.gov dataset includes provider information for COVID-19 vaccine provider locations in the U.S. Vaccines.gov is powered by VaccineFinder.',
#     'num_resources': 4,
#     'num_tags': 6,
#     'organization': {'id': '2c2fc21f-21d0-4450-af01-cf8c69b44156',
#      'name': 'hhs-gov',
#      'title': 'U.S. Department of Health & Human Services',
#      'type': 'organization',
#      'description': '',
#      'image_url': 'https://www.hhs.gov/sites/default/files/web/images/seal_blue_gold_hi_res.jpg',
#      'created': '2020-11-10T14:14:03.176362',
#      'is_organization': True,
#      'approval_status': 'approved',
#      'state': 'active'},
#     'owner_org': '2c2fc21f-21d0-4450-af01-cf8c69b44156',
#     'private': False,
#     'state': 'active',
#     'title': 'Vaccines.gov: COVID-19 vaccinating provider locations',
#     'type': 'dataset',
#     'url': None,
#     'version': None,
#     'extras': [{'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'source_hash',
#       'value': '9608d5a14068ee5bfccc99404a5630ad3a073513'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'bureauCode', 'value': ['009:20']},
#      {'key': 'identifier',
#       'value': 'https://data.cdc.gov/api/views/5jp2-pgaw'},
#      {'key': 'issued', 'value': '2022-04-20'},
#      {'key': 'landingPage', 'value': 'https://data.cdc.gov/d/5jp2-pgaw'},
#      {'key': 'license',
#       'value': 'http://opendefinition.org/licenses/odc-odbl/'},
#      {'key': 'modified', 'value': '2023-04-01'},
#      {'key': 'programCode', 'value': ['009:020']},
#      {'key': 'publisher',
#       'value': 'Centers for Disease Control and Prevention'},
#      {'key': 'theme', 'value': ['Vaccinations']},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'catalog_@id', 'value': 'https://healthdata.gov/data.json'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_object_id',
#       'value': 'bfed24e2-3bc4-44cc-9f85-0f0c24d24be4'},
#      {'key': 'harvest_source_id',
#       'value': '651e43b2-321c-4e4c-b86a-835cfc342cb0'},
#      {'key': 'harvest_source_title', 'value': 'Healthdata.gov'}],
#     'resources': [{'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-07-09T13:31:43.235460',
#       'description': '',
#       'format': 'CSV',
#       'hash': '',
#       'id': 'bba8885e-0ccb-4260-bf91-989e7f7ba2e6',
#       'last_modified': None,
#       'metadata_modified': '2021-07-09T13:31:43.235460',
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Comma Separated Values File',
#       'no_real_name': True,
#       'package_id': '93569e24-9a21-468d-b61f-00257c9a6b82',
#       'position': 0,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://data.cdc.gov/api/views/5jp2-pgaw/rows.csv?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-07-09T13:31:43.235467',
#       'description': '',
#       'format': 'RDF',
#       'hash': '',
#       'id': '70c120fe-7270-498d-8c26-4f674dbf2ae7',
#       'last_modified': None,
#       'metadata_modified': '2021-07-09T13:31:43.235467',
#       'mimetype': 'application/rdf+xml',
#       'mimetype_inner': None,
#       'name': 'RDF File',
#       'no_real_name': True,
#       'package_id': '93569e24-9a21-468d-b61f-00257c9a6b82',
#       'position': 1,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://data.cdc.gov/api/views/5jp2-pgaw/rows.rdf?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-07-09T13:31:43.235470',
#       'description': '',
#       'format': 'JSON',
#       'hash': '',
#       'id': 'b8469b0d-6180-489f-bd70-9d2271dd5486',
#       'last_modified': None,
#       'metadata_modified': '2021-07-09T13:31:43.235470',
#       'mimetype': 'application/json',
#       'mimetype_inner': None,
#       'name': 'JSON File',
#       'no_real_name': True,
#       'package_id': '93569e24-9a21-468d-b61f-00257c9a6b82',
#       'position': 2,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://data.cdc.gov/api/views/5jp2-pgaw/rows.json?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2021-07-09T13:31:43.235472',
#       'description': '',
#       'format': 'XML',
#       'hash': '',
#       'id': '977ffdb1-dcf2-4c8e-8184-1b5249c58d3f',
#       'last_modified': None,
#       'metadata_modified': '2021-07-09T13:31:43.235472',
#       'mimetype': 'application/xml',
#       'mimetype_inner': None,
#       'name': 'XML File',
#       'no_real_name': True,
#       'package_id': '93569e24-9a21-468d-b61f-00257c9a6b82',
#       'position': 3,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://data.cdc.gov/api/views/5jp2-pgaw/rows.xml?accessType=DOWNLOAD',
#       'url_type': None}],
#     'tags': [{'display_name': 'covid-19',
#       'id': 'af0c031e-ec6e-482c-b12e-90c7c320c38d',
#       'name': 'covid-19',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'providers',
#       'id': 'b53afac9-e383-4006-8fe4-f85ad542b796',
#       'name': 'providers',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'vaccination-locations',
#       'id': '77e1c73d-9d08-4cb0-89ca-a46ddd7635d1',
#       'name': 'vaccination-locations',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'vaccination-sites',
#       'id': 'f860c105-454e-41f4-ac11-221285d34ed1',
#       'name': 'vaccination-sites',
#       'state': 'active',
#       'vocabulary_id': None},
# ...
#      {'key': 'harvest_object_id',
#       'value': '69bd9c19-ba03-4e31-9394-8bf352fbc0aa'},
#      {'key': 'harvest_source_id',
#       'value': '651e43b2-321c-4e4c-b86a-835cfc342cb0'},
#      {'key': 'harvest_source_title', 'value': 'Healthdata.gov'}],
#     'resources': [{'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2022-03-18T09:39:57.056395',
#       'description': '',
#       'format': 'CSV',
#       'hash': '',
#       'id': 'fb677d79-7a24-42ea-8320-d2055d4aaf8c',
#       'last_modified': None,
#       'metadata_modified': '2022-03-18T09:39:57.056395',
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Comma Separated Values File',
#       'no_real_name': True,
#       'package_id': '4d1914bc-42ad-4eec-b505-07a699f73d1c',
#       'position': 0,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/6m8a-tsjg/rows.csv?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2022-03-18T09:39:57.056402',
#       'describedBy': 'https://healthdata.gov/api/views/6m8a-tsjg/columns.rdf',
#       'describedByType': 'application/rdf+xml',
#       'description': '',
#       'format': 'RDF',
#       'hash': '',
#       'id': '1547a819-a4fe-497c-be72-541eec9412b6',
#       'last_modified': None,
#       'metadata_modified': '2022-03-18T09:39:57.056402',
#       'mimetype': 'application/rdf+xml',
#       'mimetype_inner': None,
#       'name': 'RDF File',
#       'no_real_name': True,
#       'package_id': '4d1914bc-42ad-4eec-b505-07a699f73d1c',
#       'position': 1,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/6m8a-tsjg/rows.rdf?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2022-03-18T09:39:57.056405',
#       'describedBy': 'https://healthdata.gov/api/views/6m8a-tsjg/columns.json',
#       'describedByType': 'application/json',
#       'description': '',
#       'format': 'JSON',
#       'hash': '',
#       'id': '8fb6b5b2-3835-496a-b386-d1bc01055d58',
#       'last_modified': None,
#       'metadata_modified': '2022-03-18T09:39:57.056405',
#       'mimetype': 'application/json',
#       'mimetype_inner': None,
#       'name': 'JSON File',
#       'no_real_name': True,
#       'package_id': '4d1914bc-42ad-4eec-b505-07a699f73d1c',
#       'position': 2,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/6m8a-tsjg/rows.json?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2022-03-18T09:39:57.056408',
#       'describedBy': 'https://healthdata.gov/api/views/6m8a-tsjg/columns.xml',
#       'describedByType': 'application/xml',
#       'description': '',
#       'format': 'XML',
#       'hash': '',
#       'id': '7295b4ac-6377-4055-90be-66e8e3fb2148',
#       'last_modified': None,
#       'metadata_modified': '2022-03-18T09:39:57.056408',
#       'mimetype': 'application/xml',
#       'mimetype_inner': None,
#       'name': 'XML File',
#       'no_real_name': True,
#       'package_id': '4d1914bc-42ad-4eec-b505-07a699f73d1c',
#       'position': 3,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://healthdata.gov/api/views/6m8a-tsjg/rows.xml?accessType=DOWNLOAD',
#       'url_type': None}],
#     'tags': [{'display_name': 'covid-19',
#       'id': 'af0c031e-ec6e-482c-b12e-90c7c320c38d',
#       'name': 'covid-19',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'covid-19-therapeutic',
#       'id': '878dbd0a-24ec-4332-bb37-82c085907215',
#       'name': 'covid-19-therapeutic',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'hhs-covid-19',
#       'id': '2e6f5255-415b-47af-ab10-42b3b38e6919',
#       'name': 'hhs-covid-19',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'groups': [],
#     'relationships_as_subject': [],
#     'relationships_as_object': []},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '1ecd1fb1-1be6-46bb-b90d-07a0762ed104',
#     'id': '42bba802-d374-43ce-9c12-d444b1c09069',
#     'isopen': False,
#     'license_id': 'other-license-specified',
#     'license_title': 'other-license-specified',
#     'maintainer': 'Blake Schaeffer',
#     'maintainer_email': 'schaeffer.blake@epa.gov',
#     'metadata_created': '2023-04-02T17:43:28.740352',
#     'metadata_modified': '2023-04-02T17:43:28.740357',
#     'name': 'national-seagrass',
#     'notes': 'Using WorldView-2 and WorldView-3 imagery to classify seagrass in coastal ecosystems. \n\nThis dataset is associated with the following publication:\nCoffer, M., D. Graybill, P. Whitman, B. Schaeffer, W. Salls, R. Zimmerman, V. Hill, M. Lebrasse, J. Li, D. Keith, J. Kaldy, P. Colarusso, G. Raulerson, D. Ward, and W.J. Kenworthy. Providing a framework for seagrass mapping in United States coastal ecosystems using high spatial resolution satellite imagery.   JOURNAL OF ENVIRONMENTAL MANAGEMENT. Elsevier Science Ltd, New York, NY, USA, 337: 117669, (2023).',
#     'num_resources': 1,
#     'num_tags': 6,
#     'organization': {'id': '82b85475-f85d-404a-b95b-89d1a42e9f6b',
#      'name': 'epa-gov',
#      'title': 'U.S. Environmental Protection Agency',
#      'type': 'organization',
#      'description': 'Our mission is to protect human health and the environment. ',
#      'image_url': 'http://edg.epa.gov/EPALogo.svg',
#      'created': '2020-11-10T15:10:42.298896',
#      'is_organization': True,
#      'approval_status': 'approved',
#      'state': 'active'},
#     'owner_org': '82b85475-f85d-404a-b95b-89d1a42e9f6b',
#     'private': False,
#     'state': 'active',
#     'title': 'National seagrass',
#     'type': 'dataset',
#     'url': None,
#     'version': None,
#     'extras': [{'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'source_hash',
#       'value': '97f57c12f3e163239b2fd617d65f0fe8bda407ff'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'bureauCode', 'value': ['020:00']},
#      {'key': 'identifier', 'value': 'https://doi.org/10.23719/1528146'},
#      {'key': 'license',
#       'value': 'https://pasteur.epa.gov/license/sciencehub-license.html'},
#      {'key': 'modified', 'value': '2020-08-03'},
#      {'key': 'programCode', 'value': ['020:000']},
#      {'key': 'publisher',
#       'value': 'U.S. EPA Office of Research and Development (ORD)'},
#      {'key': 'references',
#       'value': ['https://doi.org/10.1016/j.jenvman.2023.117669']},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'publisher_hierarchy',
#       'value': 'U.S. Government > U.S. Environmental Protection Agency > U.S. EPA Office of Research and Development (ORD)'},
#      {'key': 'harvest_object_id',
#       'value': '3c33482e-2d6c-4ec4-ac5f-f11a77fa86f7'},
#      {'key': 'harvest_source_id',
#       'value': '04b59eaf-ae53-4066-93db-80f2ed0df446'},
#      {'key': 'harvest_source_title', 'value': 'EPA ScienceHub'}],
#     'resources': [{'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2023-04-02T17:43:28.813115',
#       'description': 'Coffer_et_al_seagrass.zip',
#       'format': 'ZIP',
#       'hash': '',
#       'id': '4913a84b-4940-4f1f-acb0-d3c3f452e3fe',
#       'last_modified': None,
#       'metadata_modified': '2023-04-02T17:43:28.721747',
#       'mimetype': 'application/x-zip-compressed',
#       'mimetype_inner': None,
#       'name': 'Coffer_et_al_seagrass.zip',
#       'package_id': '42bba802-d374-43ce-9c12-d444b1c09069',
#       'position': 0,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://pasteur.epa.gov/uploads/10.23719/1528146/Coffer_et_al_seagrass.zip',
#       'url_type': None}],
#     'tags': [{'display_name': 'coastal-monitoring',
#       'id': '6d99d75e-799d-4a50-9b79-bb3f856f7443',
#       'name': 'coastal-monitoring',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'image-classification',
#       'id': '59f88621-9c3c-4c87-80b0-81df49b25a33',
#       'name': 'image-classification',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'satellite-remote-sensing',
#       'id': '0232307c-981e-45c7-acbf-8c2135b87ca5',
#       'name': 'satellite-remote-sensing',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'seagrass',
#       'id': 'cb0ff180-772d-4263-8da2-6054ec47a654',
#       'name': 'seagrass',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'worldview-2',
#       'id': '650db9a4-7784-436f-a4aa-08d6dac4b15d',
#       'name': 'worldview-2',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'worldview-3',
#       'id': 'bf23a6f3-b197-4238-afeb-b4ec12e470da',
#       'name': 'worldview-3',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'groups': [],
#     'relationships_as_subject': [],
#     'relationships_as_object': []},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '2b785922-9f13-491b-a3c2-2a40acbd80c2',
#     'id': '6a1feac3-390d-40bd-a7b1-126fea84be78',
#     'isopen': False,
#     'license_id': 'other-license-specified',
#     'license_title': 'other-license-specified',
#     'maintainer': 'Andrew Nebus',
#     'maintainer_email': 'no-reply@opendata.fcc.gov',
#     'metadata_created': '2020-11-12T13:20:14.500505',
#     'metadata_modified': '2023-04-02T17:43:19.948512',
#     'name': 'cgb-consumer-complaints-data',
#     'notes': 'Individual informal consumer complaint data detailing complaints filed with the Consumer Help Center beginning October 31, 2014. This data represents information selected by the consumer. The FCC does not verify the facts alleged in these complaints.',
#     'num_resources': 4,
#     'num_tags': 3,
#     'organization': {'id': 'bb10fdb9-d96f-4284-9a5f-9ed269d9dbcb',
#      'name': 'fcc-gov',
#      'title': 'Federal Communications Commission',
#      'type': 'organization',
#      'description': '',
#      'image_url': 'https://transition.fcc.gov/files/logos/fcc-logo_teal-on-white.jpg',
#      'created': '2020-11-10T17:36:32.009064',
#      'is_organization': True,
#      'approval_status': 'approved',
#      'state': 'active'},
#     'owner_org': 'bb10fdb9-d96f-4284-9a5f-9ed269d9dbcb',
#     'private': False,
#     'state': 'active',
#     'title': 'CGB - Consumer Complaints Data',
#     'type': 'dataset',
#     'url': None,
#     'version': None,
#     'extras': [{'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'source_hash',
#       'value': '044e1ee0f5be515a4aa243e821267fb69be93ecd'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'bureauCode', 'value': ['356:00']},
#      {'key': 'identifier',
#       'value': 'https://opendata.fcc.gov/api/views/3xyp-aqkj'},
#      {'key': 'issued', 'value': '2021-08-12'},
#      {'key': 'landingPage', 'value': 'https://opendata.fcc.gov/d/3xyp-aqkj'},
#      {'key': 'license', 'value': 'https://www.usa.gov/government-works'},
#      {'key': 'modified', 'value': '2023-04-02'},
#      {'key': 'programCode', 'value': ['000:000']},
#      {'key': 'publisher', 'value': 'opendata.fcc.gov'},
#      {'key': 'theme', 'value': ['Consumer']},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'catalog_@id', 'value': 'https://opendata.fcc.gov/data.json'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_object_id',
#       'value': '932d4b9b-9ed4-4c06-b9ce-b268ce92ca88'},
#      {'key': 'harvest_source_id',
#       'value': '2228b51b-f6ea-4e22-88d0-3dca800a0246'},
#      {'key': 'harvest_source_title', 'value': 'FCC Data.json'}],
#     'resources': [{'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2020-11-12T13:20:14.525774',
#       'description': '',
#       'format': 'CSV',
#       'hash': '',
#       'id': 'd7721568-02af-44da-9e88-6582d686c34d',
#       'last_modified': None,
#       'metadata_modified': '2020-11-12T13:20:14.525774',
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Comma Separated Values File',
#       'no_real_name': True,
#       'package_id': '6a1feac3-390d-40bd-a7b1-126fea84be78',
#       'position': 0,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://opendata.fcc.gov/api/views/3xyp-aqkj/rows.csv?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2020-11-12T13:20:14.525784',
#       'describedBy': 'https://opendata.fcc.gov/api/views/3xyp-aqkj/columns.rdf',
#       'describedByType': 'application/rdf+xml',
#       'description': '',
#       'format': 'RDF',
#       'hash': '',
#       'id': 'b0b9e46a-612f-489a-8583-893e2dba7cca',
#       'last_modified': None,
#       'metadata_modified': '2020-11-12T13:20:14.525784',
#       'mimetype': 'application/rdf+xml',
#       'mimetype_inner': None,
#       'name': 'RDF File',
#       'no_real_name': True,
#       'package_id': '6a1feac3-390d-40bd-a7b1-126fea84be78',
#       'position': 1,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://opendata.fcc.gov/api/views/3xyp-aqkj/rows.rdf?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2020-11-12T13:20:14.525791',
#       'describedBy': 'https://opendata.fcc.gov/api/views/3xyp-aqkj/columns.json',
#       'describedByType': 'application/json',
#       'description': '',
#       'format': 'JSON',
#       'hash': '',
#       'id': '44e5dcdd-6731-4d43-b387-177d5ab6c7fb',
#       'last_modified': None,
#       'metadata_modified': '2020-11-12T13:20:14.525791',
#       'mimetype': 'application/json',
#       'mimetype_inner': None,
#       'name': 'JSON File',
#       'no_real_name': True,
#       'package_id': '6a1feac3-390d-40bd-a7b1-126fea84be78',
#       'position': 2,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://opendata.fcc.gov/api/views/3xyp-aqkj/rows.json?accessType=DOWNLOAD',
#       'url_type': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2020-11-12T13:20:14.525796',
#       'describedBy': 'https://opendata.fcc.gov/api/views/3xyp-aqkj/columns.xml',
#       'describedByType': 'application/xml',
#       'description': '',
#       'format': 'XML',
#       'hash': '',
#       'id': 'fdf1c0a4-6060-43a1-b26f-cdc3fb463949',
#       'last_modified': None,
#       'metadata_modified': '2020-11-12T13:20:14.525796',
#       'mimetype': 'application/xml',
#       'mimetype_inner': None,
#       'name': 'XML File',
#       'no_real_name': True,
#       'package_id': '6a1feac3-390d-40bd-a7b1-126fea84be78',
#       'position': 3,
#       'resource_type': None,
#       'size': None,
#       'state': 'active',
#       'url': 'https://opendata.fcc.gov/api/views/3xyp-aqkj/rows.xml?accessType=DOWNLOAD',
#       'url_type': None}],
#     'tags': [{'display_name': 'fcc',
#       'id': '9937cc00-6f45-4e38-a3f0-a767879f2495',
#       'name': 'fcc',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'fcc-consumer-complaints',
#       'id': 'c3fcf78a-8808-42e8-bd08-16688243fbb4',
#       'name': 'fcc-consumer-complaints',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'fcc-consumer-inquiry',
#       'id': 'e8e1548a-2d7e-48f0-8173-7a709c64a0f2',
#       'name': 'fcc-consumer-inquiry',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'groups': [],
#     'relationships_as_subject': [],
#     'relationships_as_object': []}],
#   'sort': 'metadata_modified desc',
#   'search_facets': {}}}

# %%
import re

def slugify(s):
    """Take a string and 'slugify' it

    Parameters
    ----------
    s : str
        A string to format without spaces, lower case, basic sluggify
    """
    s = s.lower().strip()
    s = re.sub(r'[^\w\s-]', '', s)
    s = re.sub(r'[\s_-]+', '-', s)
    s = re.sub(r'^-+|-+$', '', s)
    return s

# %%
for record in data['result']['results']:
    doc = {
        'id': record['id'],
        'layout': 'record',
        'title': record['title'],
        'licence': record['license_title'],
        'type': record['type'],
        'description': record['notes'],
        'resource_count': record['num_resources'],
        'record_url': 'https://catalog.data.gov/' + record['type'] + '/' + record['name'],
        'author': record['author'],
        'data_provider': record['organization']['title'],
        'date': record['metadata_created'],
        'format': record['resources'][0]['format']
    }

    frontmatter = yaml.dump(doc, sort_keys=False)
    filepath = "../_records/" + slugify(record['title']) + '.md'

    with open(filepath, 'w') as f:
        f.write('---\n')
        f.write(frontmatter)
        f.write('---\n\n')

# %%
# get 1 pages of Europeana records

# https://github.com/europeana/rd-europeana-python-api#usage
import pyeuropeana.apis as apis
import pyeuropeana.utils as utils

results = apis.search(
    query = '*',
    # qf = '(skos_concept:"http://data.europeana.eu/concept/base/48" AND TYPE:IMAGE)',
    reusability = 'open AND permission',
    media = True,
    thumbnail = True,
    landingpage = True,
    colourpalette = '#0000FF',
    theme = 'photography',
    sort = 'europeana_id',
    # profile = 'rich',
    rows = 10,
) # this gives you full response metadata along with cultural heritage object metadata

# %%
for item in results['items']:
    title_string = ' '.join(item['title'])
    doc = {
        'id': item['id'],
        'layout': 'record',
        'title': title_string,
        'licence': item['rights'],
        'description': item.get('description'),
        'thumbnail': item['edmPreview'],
        'record_url': item['guid'],
        'data_provider': item['dataProvider'],
        # 'languages': item['dcLanguage'],
        # 'latitude': item['edmPlaceLatitude'],
        # 'longitude': item['edmPlaceLongitude'],
        'date': item['timestamp_created']
    }

    frontmatter = yaml.dump(doc, sort_keys=False)
    filepath = "../_records/" + slugify(title_string) + '.md'

    with open(filepath, 'w') as f:
        f.write('---\n')
        f.write(frontmatter)
        f.write('---\n\n')
